# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Market_Basket_Optimisation.csv',sep=',')
df.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# ...

# %%
dataset = [['Jupe', 'Baskets', 'Écharpe', 'Pantalon', 'Chapeau'],

['Lunettes de soleil', 'Jupe', 'Baskets', 'Pantalon', 'Chapeau'],

['Robe', 'Sandales', 'Écharpe', 'Pantalon', 'Talons'],

['Robe', 'Collier', 'Boucles d’oreilles', 'Écharpe', 'Chapeau', 'Talons', 'Chapeau'],

['Boucles d’oreilles', 'Jupe', 'Jupe', 'Écharpe', 'Chemise', 'Pantalon']]

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)    #Apply one-hot-encoding on our dataset
df=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df
# Out:
#    Baskets  Boucles d’oreilles  Chapeau  Chemise  Collier   Jupe  \
# 0     True               False     True    False    False   True
# 1     True               False     True    False    False   True
# 2    False               False    False    False    False  False
# 3    False                True     True    False     True  False
# 4    False                True    False     True    False   True
#
#    Lunettes de soleil  Pantalon   Robe  Sandales  Talons  Écharpe
# 0               False      True  False     False   False     True
# 1                True      True  False     False   False    False
# 2               False      True   True      True    True     True
# 3               False     False   True     False    True     True
# 4               False      True  False     False   False     True

# %%
from mlxtend.frequent_patterns import apriori
apriori(df, min_support=0.6)
# Out:
#    support itemsets
# 0      0.6      (2)
# 1      0.6      (5)
# 2      0.8      (7)
# 3      0.8     (11)
# 4      0.6   (5, 7)
# 5      0.6  (11, 7)

# %%
frequent_itemsets=apriori(df, min_support=0.6, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
# Out:
#    support             itemsets
# 0      0.6            (Chapeau)
# 1      0.6               (Jupe)
# 2      0.8           (Pantalon)
# 3      0.8            (Écharpe)
# 4      0.6     (Jupe, Pantalon)
# 5      0.6  (Écharpe, Pantalon)

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7) # associate itemsets with confidence over 70%.
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0      (Jupe)  (Pantalon)                 0.6                 0.8      0.6
# 1  (Pantalon)      (Jupe)                 0.8                 0.6      0.6
# 2   (Écharpe)  (Pantalon)                 0.8                 0.8      0.6
# 3  (Pantalon)   (Écharpe)                 0.8                 0.8      0.6
#
#    confidence    lift  leverage  conviction
# 0        1.00  1.2500      0.12         inf
# 1        0.75  1.2500      0.12         1.6
# 2        0.75  0.9375     -0.04         0.8
# 3        0.75  0.9375     -0.04         0.8

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="lift",min_threshold=1.25)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0      (Jupe)  (Pantalon)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0         1.0  1.25      0.12         inf

# %%
import pandas as pd
import numpy as np

dfg = pd.read_csv('Market_Basket_Optimisation.csv',sep=',')
dfg.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# ...

# %%
dfg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   shrimp             7500 non-null   object
#  1   almonds            5746 non-null   object
#  2   avocado            4388 non-null   object
#  3   vegetables mix     3344 non-null   object
#  4   green grapes       2528 non-null   object
#  5   whole weat flour   1863 non-null   object
#  6   yams               1368 non-null   object
#  7   cottage cheese     980 non-null    object
#  8   energy drink       653 non-null    object
#  9   tomato juice       394 non-null    object
#  10  low fat yogurt     255 non-null    object
#  11  green tea          153 non-null    object
#  12  honey              86 non-null     object
#  13  salad              46 non-null     object
#  14  mineral water      24 non-null     object
#  15  salmon             7 non-null      object
# ...

# %%
print('Percent of missing "olive oil" records is %.2f%%' %((dfg['olive oil'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "spinach" records is %.2f%%' %((dfg['spinach'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "frozen smoothie" records is %.2f%%' %((dfg['frozen smoothie'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "antioxydant juice" records is %.2f%%' %((dfg['antioxydant juice'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "salmon" records is %.2f%%' %((dfg['salmon'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "mineral water" records is %.2f%%' %((dfg['mineral water'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "salad" records is %.2f%%' %((dfg['salad'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "honey" records is %.2f%%' %((dfg['honey'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "green tea" records is %.2f%%' %((dfg['green tea'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "low fat yogurt" records is %.2f%%' %((dfg['low fat yogurt'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "tomato juice" records is %.2f%%' %((dfg['tomato juice'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "energy drink" records is %.2f%%' %((dfg['energy drink'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "cottage cheese" records is %.2f%%' %((dfg['cottage cheese'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "yams" records is %.2f%%' %((dfg['yams'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "whole weat flour" records is %.2f%%' %((dfg['whole weat flour'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "green grapes" records is %.2f%%' %((dfg['green grapes'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "vegetables mix" records is %.2f%%' %((dfg['vegetables mix'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "avocado" records is %.2f%%' %((dfg['avocado'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "almonds" records is %.2f%%' %((dfg['almonds'].isnull().sum()/dfg.shape[0])*100))
print('Percent of missing "shrimp" records is %.2f%%' %((dfg['shrimp'].isnull().sum()/dfg.shape[0])*100))
# Out:
# Percent of missing "olive oil" records is 100.00%
# Percent of missing "spinach" records is 99.97%
# Percent of missing "frozen smoothie" records is 99.96%
# Percent of missing "antioxydant juice" records is 99.96%
# Percent of missing "salmon" records is 99.91%
# Percent of missing "mineral water" records is 99.68%
# Percent of missing "salad" records is 99.39%
# Percent of missing "honey" records is 98.85%
# Percent of missing "green tea" records is 97.96%
# Percent of missing "low fat yogurt" records is 96.60%
# Percent of missing "tomato juice" records is 94.75%
# Percent of missing "energy drink" records is 91.29%
# Percent of missing "cottage cheese" records is 86.93%
# Percent of missing "yams" records is 81.76%
# Percent of missing "whole weat flour" records is 75.16%
# Percent of missing "green grapes" records is 66.29%
# Percent of missing "vegetables mix" records is 55.41%
# Percent of missing "avocado" records is 41.49%
# Percent of missing "almonds" records is 23.39%
# ...

# %%
#df.replace(["n.a","?","NaN"], np.nan, inplace=True)
dfg.drop(columns=['olive oil', 'spinach', 'frozen smoothie', 'antioxydant juice','salmon', 'mineral water', 'salad', 'honey', 'green tea','low fat yogurt', 'tomato juice', 'energy drink', 'cottage cheese', 'yams','whole weat flour','green grapes','vegetables mix'],inplace=True)

# %%
dfg.head()
# Out:
#            shrimp    almonds     avocado
# 0         burgers  meatballs        eggs
# 1         chutney        NaN         NaN
# 2          turkey    avocado         NaN
# 3   mineral water       milk  energy bar
# 4  low fat yogurt        NaN         NaN

# %%
dfg["avocado"] = dfg["avocado"].replace(np.nan, "NaN")
dfg["shrimp"] = dfg["shrimp"].replace(np.nan, "NaN")
dfg["almonds"] = dfg["almonds"].replace(np.nan, "NaN")

# %%
df1 = dfg.values.tolist()

# %%
df1
# Out:
# [['burgers', 'meatballs', 'eggs'],
#  ['chutney', 'NaN', 'NaN'],
#  ['turkey', 'avocado', 'NaN'],
#  ['mineral water', 'milk', 'energy bar'],
#  ['low fat yogurt', 'NaN', 'NaN'],
#  ['whole wheat pasta', 'french fries', 'NaN'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries', 'NaN', 'NaN'],
#  ['eggs', 'pet food', 'NaN'],
#  ['cookies', 'NaN', 'NaN'],
#  ['turkey', 'burgers', 'mineral water'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon', 'NaN'],
#  ['mineral water', 'NaN', 'NaN'],
#  ['shrimp', 'chocolate', 'chicken'],
#  ['turkey', 'eggs', 'NaN'],
#  ['turkey', 'fresh tuna', 'tomatoes'],
#  ['meatballs', 'milk', 'honey'],
#  ['red wine', 'shrimp', 'pasta'],
#  ['rice', 'sparkling water', 'NaN'],
#  ['spaghetti', 'mineral water', 'ham'],
#  ['burgers', 'grated cheese', 'shrimp'],
#  ['eggs', 'NaN', 'NaN'],
#  ['parmesan cheese', 'spaghetti', 'soup'],
# ...

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te=TransactionEncoder()
te_ary=te.fit(df1).transform(df1)    #Apply one-hot-encoding on our dataset
df=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df
# Out:
#         NaN  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0     False    False              False      False    False        False
# 1      True    False              False      False    False        False
# 2      True    False              False      False     True        False
# 3     False    False              False      False    False        False
# 4      True    False              False      False    False        False
# ...     ...      ...                ...        ...      ...          ...
# 7495  False    False              False      False    False        False
# 7496  False    False              False      False    False        False
# 7497   True    False              False      False    False        False
# 7498   True    False              False      False    False        False
# 7499  False    False              False      False    False        False
#
#       bacon  barbecue sauce  black tea  blueberries  ...  turkey  \
# ...

# %%
from mlxtend.frequent_patterns import apriori

apriori(df, min_support=0.1)
# Out:
#     support itemsets
# 0  0.414933      (0)
# 1  0.105067     (25)
# 2  0.107467     (37)
# 3  0.191467     (72)
# 4  0.139200     (99)

# %%
frequent_itemsets=apriori(df, min_support=0.1, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
# Out:
#     support         itemsets
# 0  0.414933            (NaN)
# 1  0.105067      (chocolate)
# 2  0.107467           (eggs)
# 3  0.191467  (mineral water)
# 4  0.139200      (spaghetti)

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.0) # associate itemsets with confidence over 70%.
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="lift",min_threshold=0.1)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
df.shape
# Out:
# (7500, 119)

# %%
df.isna().sum()
# Out:
# NaN                  0
# almonds              0
# antioxydant juice    0
# asparagus            0
# avocado              0
#                     ..
# whole wheat pasta    0
# whole wheat rice     0
# yams                 0
# yogurt cake          0
# zucchini             0
# Length: 119, dtype: int64

# %%
df.describe(include='all')
# Out:
#           NaN almonds antioxydant juice asparagus avocado babies food  bacon  \
# count    7500    7500              7500      7500    7500        7500   7500
# unique      2       2                 2         2       2           2      2
# top     False   False             False     False   False       False  False
# freq     4388    7426              7460      7490    7334        7486   7474
#
#        barbecue sauce black tea blueberries  ... turkey vegetables mix  \
# count            7500      7500        7500  ...   7500           7500
# unique              2         2           2  ...      2              2
# top             False     False       False  ...  False          False
# freq             7470      7445        7475  ...   7031           7378
#
#        water spray white wine whole weat flour whole wheat pasta  \
# count         7500       7500             7500              7500
# unique           2          2                2                 2
# ...

# %%
df.columns
# Out:
# Index(['NaN', 'almonds', 'antioxydant juice', 'asparagus', 'avocado',
#        'babies food', 'bacon', 'barbecue sauce', 'black tea', 'blueberries',
#        ...
#        'turkey', 'vegetables mix', 'water spray', 'white wine',
#        'whole weat flour', 'whole wheat pasta', 'whole wheat rice', 'yams',
#        'yogurt cake', 'zucchini'],
#       dtype='object', length=119)

# %%
df.head(1)
# Out:
#      NaN  almonds  antioxydant juice  asparagus  avocado  babies food  bacon  \
# 0  False    False              False      False    False        False  False
#
#    barbecue sauce  black tea  blueberries  ...  turkey  vegetables mix  \
# 0           False      False        False  ...   False           False
#
#    water spray  white wine  whole weat flour  whole wheat pasta  \
# 0        False       False             False              False
#
#    whole wheat rice   yams  yogurt cake  zucchini
# 0             False  False        False     False
#
# [1 rows x 119 columns]

# %%
#df['shrimp'].nunique()
